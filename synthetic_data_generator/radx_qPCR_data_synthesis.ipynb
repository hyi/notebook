# %% [markdown]
# # Howso Enterprise Data Synthesis Workflow
#
# This notebook will provide a high level overview of the synthetic data generation process, including the final data evaluation for accuracy vs. privacy trade off. More details on each data generation step will be covered in subsequent notebooks.
#
# The process can be broken down into six key steps as illustrated in the diagram below.

# %% [markdown]
# <img src="static/synthesizer_process_workflow.png" width="1080">

# %% [markdown]
# ## Step 1: Load Data

# %%
from pathlib import Path

from IPython.display import (
    display,
    Markdown,
)
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from howso.enterprise import Howso, infer_feature_attributes

# %%
data_path = Path("data", "radx", "rad_015_941-01_qPCR_ProcessedData_DATA_origcopy_v1.csv")
df = pd.read_csv(data_path)
df = df.reset_index(drop=True)

print(df.columns)
# Out:
# Index(['sample_id', 'pcr_target', 'sars_cov2_avg_conc', 'sars_cov2_units',
#        'hum_frac_target_mic', 'hum_frac_mic_conc', 'hum_frac_mic_unit',
#        'other_norm_name', 'other_norm_conc', 'other_norm_unit',
#        'inhibition_detect'],
#       dtype='object')

# %% [markdown]
# ## Step 2: Map Data
#
# Confirm the data types are detected correctly.

# %%
features = infer_feature_attributes(df)

# As this is just a recipe notebook and not an attempt at creating anonymous data, we are setting the nominal features
# as `non_sensitive`. When creating anonymous data, you should only set nominal features as non-sensitive if they are
# truly non-sensitive. For example, when attempting to create anonymous data, we strongly recommend that nominals are
# encoded, which can be achieved by the following utility code:
# features = infer_features_attributes(df_orig, attempt_infer_extended_nominals=True)
for feature_name in features.get_names(types=("nominal", "ordinal")):
    features[feature_name]["non_sensitive"] = True

features.to_dataframe()
# Out:
#                            type decimal_places     bounds                     \
#                                                allow_null  min           max
# sample_id               nominal            NaN       True  NaN           NaN
# pcr_target              nominal            NaN       True  NaN           NaN
# sars_cov2_avg_conc   continuous            2.0       True  0.0  5.843472e+07
# sars_cov2_units         nominal            NaN       True  NaN           NaN
# hum_frac_target_mic     nominal            NaN       True  NaN           NaN
# hum_frac_mic_conc    continuous            2.0       True  0.0  6.520107e+10
# hum_frac_mic_unit       nominal            NaN       True  NaN           NaN
# other_norm_name         nominal            NaN       True  NaN           NaN
# other_norm_conc      continuous            2.0       True  0.0  2.668245e+07
# other_norm_unit         nominal            NaN       True  NaN           NaN
# inhibition_detect       nominal            NaN       True  NaN           NaN
#
#                                                data_type non_sensitive  \
#                     observed_min  observed_max
# sample_id                    NaN           NaN       NaN          True
# pcr_target                   NaN           NaN       NaN          True
# sars_cov2_avg_conc           0.0  3.544245e+07    number           NaN
# sars_cov2_units              NaN           NaN       NaN          True
# hum_frac_target_mic          NaN           NaN       NaN          True
# hum_frac_mic_conc            0.0  3.954645e+10    number           NaN
# hum_frac_mic_unit            NaN           NaN       NaN          True
# other_norm_name              NaN           NaN       NaN          True
# other_norm_conc              0.0  1.618372e+07    number           NaN
# other_norm_unit              NaN           NaN       NaN          True
# inhibition_detect            NaN           NaN       NaN          True
#
#                     original_type
#                         data_type size
# sample_id                  string  NaN
# pcr_target                 string  NaN
# sars_cov2_avg_conc        numeric  8.0
# sars_cov2_units            string  NaN
# hum_frac_target_mic        string  NaN
# hum_frac_mic_conc         numeric  8.0
# hum_frac_mic_unit          string  NaN
# other_norm_name            string  NaN
# other_norm_conc           numeric  8.0
# other_norm_unit            string  NaN
# inhibition_detect          string  NaN

# %% [markdown]
# ## Step 3: Set Desired Parameters
#
# - Desired parameter: Synthesizer allows the user to tune synthetic data based on privacy / accuracy requirements, this notebook will use the default settings which provides a good balance between accuracy and privacy

# %% [markdown]
# ## Step 4-6: Characterize Data, Generate New Data, Analyze Data
#
# > ⚠ Note: To parameterize synthesis using epsilon (differential privacy), use the `epsilon_upper_bound` parameter to `Howso.synthesize()`
# > instead of `desired_conviction`. Validator's `AnonymityPreservation` measures epsilon post-synthesis by accessing the average distance between each synthetic point and its nearest original record, which may be used to validate that the empirical epsilon is below `epsilon_upper_bound`.
#
# - Characterize Data: Synthesizer preserves the distribution in the original dataset by default and cross-shreds the original data so there will not be a 1-to-1 mapping to the original dataset to maintain privacy.
#
# - Analyze Data: Validator uses the same Trainee as Synthesizer to analyze the quality _and_ privacy of the synthesis.
#
# - Characterizing, generating, and analyzing new synthetic data with Synthesizer & Validator using the parameters described above is as simple as:

# %%
with Howso() as howso:
    print(howso.synthesize.__doc__)
# Out:
#         Synthesize the given ``source_file_name`` into ``destination_file_name``.
#
#         if a ``chunk_size`` is specified, split up the source file into
#         "chunks" of ``chunk_size`` samples and process them through Synthesizer
#         as independent data frames, but return all synthetic results together
#         in the destination file. The aim is to "divide and conquer" very large
#         data sources to be processed across multiple workers on multiple other
#         compute nodes.
#
#         Parameters
#         ----------
#         source_data : str or Path or AbstractData
#             The source data.
#         features : Dictionary or FeatureAttributesBase
#             Feature attributes. Please see ``howso.synthesizer.train()``
#             documentation for further details. If this is supplied,
#             feature_attribute_overrides is ignored.
#
#         chunk_size : int, optional
#             The desired size of each chunk. The larger the better for accuracy and
#             privacy. Smaller values here may provide better speed, however.
#             If not specified, the entire dataset will be synthesized at once and
#             these parameters will be ignored:
#
#               - grouping_features
#               - max_chunks
#               - skip_chunks
#
#         config_overrides : BaseConfiguration or Mapping, optional
#             Provide runtime overrides to the configuration in the current
#             environment.
#         max_workers : int, default 1
#             The number of Howso workers to employ in parallel.
#         debug : bool, default False
#             When True, and a chunk fails, the original chunk and the synthetic
#             chunk (if available) will be stored to disk.
#         destination_data : str or Path or AbstractData, optional
#             The destination data. If no path or AbstractData is provided,
#             output will go to `synthesized_data.parquet` in the current working
#             directory. If this file exists, a numbered variant will be used.
#         grouping_features : str or iterable of str, optional
#             The name of the column(s) whose values will be used to group rows
#             such that no two chunks contain the same values. The given field
#             must be nominal or ordinal without a declared list of `allowed`
#             values, or must be declared in the list of features in
#             `preserve_feature_values` synth_kwargs.
#
#             When time-series attributes are detected in `features` this feature
#             is internally used to synthesize the dataset in a time-series.
#             Therefore it is not possible to set this parameter to a value other
#             than the `id_feature` when using time-series.
#         max_chunks : int or None, optional
#             The maximum number of chunks to process.
#         max_original_cases : int, default 3
#             The maximum number of original cases to include in results attribute:
#             ``privacy_audit_df``. This value will be capped at the value of ``k``
#             of the optimized model parameters.
#         max_retries : int, default 3
#             The maximum number of retries per chunk.
#         max_trainees : int, optional
#             If provided raise a warning if the `max_workers` and Validator metrics
#             configuration is expected to exceed this number.
#         post_synth_callback : Callable, optional
#             (Optional) A callable to run after chunk synthesis, taking
#             a DataFrame as its only parameter.
#         privacy_audit_limit : int, default 0
#             If 1 or greater, and ``validate`` is set and configured to compute
#             AnonymityPreservation scores, then the number of cases returned is
#             limited to this value for audit_generated_cases_map().
#         privacy_audit_threshold : float, default 1.0
#             If privacy_audit_limit is not None and ``validate`` is set and configured
#             to compute AnonymityPreservation scores, then the threshold for
#             audit_generated_cases_map() is set so that all cases with a distance
#             ratio less than this value. Use `None` to return all cases (up to the
#             `privacy_audit_limit`), which is useful for obtaining a report
#             regardless of their distance ratio.
#         skip_chunks : int, default 0
#             The number of chunks to skip.
#         spool_validator_to_disk : bool, default True
#             Whether to spool Validator results to disk as chunks complete. Reduces memory usage.
#         validate : bool, default None
#             Whether to run Validator on each chunk. This is automatically
#             set to True if ``validation_options`` is set. If ``validate_options`` is
#             not set and ``validate`` is True, validation will occur with default
#             metrics.
#         validate_options : MutableMapping, optional
#             Optional parameters to pass into Validator's
#             :meth:`~howso.validator.Validator.run_metrics` method.
#
#             Additional options:
#
#             minimum_threshold : Dict or int or float, optional
#                 Minimum Validator metric desirability threshold scores. If a Dict is provided, then a
#                 per metric threshold is used. If a float or int is provided, then that value
#                 is used for all metrics. If a desirability score is below this score or is Nan,
#                 then the chunk is retried up to `max_retries` number of times. Default value is 0
#                 for all metrics if not specified. This value is exclusive except for 0.
#
#                 .. code-block:: python
#                     :caption: Example Dict:
#
#                     validator_minimum_threshold = {
#                         "AnonymityPreservation": 0.1,
#                         "DescriptiveStatistics": 0.1
#                     }
#         kwargs : Mapping, optional
#             ``Synthesizer()``, ``Synthesizer.train()`` and
#             ``Synthesizer.synthesize_cases_with_details()`` parameters.
#             See: :class:`~howso.synthesizer.Synthesizer`,
#             :meth:`~howso.synthesizer.Synthesizer.train`, and
#             :meth:`~howso.synthesizer.Synthesizer.synthesize_cases_with_details`.
#
#         Returns
#         -------
#         ChunkScalingResults
#             destination_data : AbstractData
#                 The AbstractData subclass instance that encapsulates the
#                 destination data which has already been written to disk. Call
#                 the ``get_dataframe()`` on this instance method to get a data
#                 frame for inspection.
#             validate_results : ValidatorResult or dict[str, Any]
#                 The Validator results for every synthesized chunk.
#                 Will be empty if ``validate`` is False. Will be an empty
#                 dictionary if ``howso-validator`` is not installed.
#             validate_results_aggregate : ValidatorResult or Dict
#                 The per-chunk collection of validator results.
#             privacy_report : str
#                 If parameters permit, a privacy report will be returned as a string.
#             audit_cases : pandas.DataFrame
#                 This is a data frame that relates the original and synthetic cases
#                 by their indices. This is used to generate an audit report.
#             original_audit_cases : pandas.DataFrame
#                 This is a data frame that contains the original cases nearest the
#                 synthetic cases used to generate an audit report.
#             synthetic_audit_cases : pandas.DataFrame
#                 This is a data frame that contains the synthetic cases used to
#                 generate an audit report.
#             exceptions : list of Exception
#                 A list of exceptions captured while synthesizing the chunks, if any.
#             aggregate_durations : dict[str, timedelta]
#                 The aggregated durations of processing including the total
#                 durations for ``train_time`, ``analyze_time``, ``synth_time``,
#                 ``mapping_time``, and ``validate_time``, each expressed as the
#                 cumulative elapsed time for the phase across all chunks.

# %%
tests_to_run = [
    "AnonymityPreservation",
    "DescriptiveStatistics",
    "JointProbability",
    "ModelComparison",
    # FeatureImportanceComparison is expensive and you should consider disabling it for large datasets,
    # particularly datasets with many features.
    "FeatureImportanceComparison",
]

# Instantiate our compute environment. In this case it is Howso Standalone running on a local machine.
with Howso() as howso:
    results = howso.synthesize(
        # Perform the synthesis, with validation
        source_data=df,
        features=features,
        validate_options={"metrics": tests_to_run},
        destination_data='radx_synthesized_data_qPCR.csv'
    )

display(results.destination_data.get_dataframe())
# Out:
# Version 45.0.0 of Howso Engine™ is available. You are using version 39.0.0.
# Train chunk «radx_synthesized_data_qpcr:chunk-1» with 2,351 samples took 0:00:00.441665.
# Analyze chunk «radx_synthesized_data_qpcr:chunk-1» with 2,351 samples took 0:00:02.441045.
# Synthesize chunk «radx_synthesized_data_qpcr:chunk-1» with 2,351 samples took 0:00:08.950821.
# Validate chunk «radx_synthesized_data_qpcr:chunk-1» with 2,351 samples took 0:03:12.231577.
# Validator desirability results of chunk «radx_synthesized_data_qpcr:chunk-1»: AnonymityPreservation: 5.0 | DescriptiveStatistics: 0.678 | JointProbability: 4.339 | ModelComparison: 4.156 | FeatureImportanceComparison: 1.523
# Processing complete.
# Synthesizing DataFrameData8726645126794 to radx_synthesized_data_qPCR.csv via chunks of 25,000 samples with 1 workers required 0:03:24.821159.
# Wall clock: 0:03:24.821159 (100.4%), Train: 0:00:00.441665 (0.2%),
# Analyze: 0:00:02.441045 (1.2%),
# Synthesis: 0:00:08.950821 (4.4%),
# Validation: 0:03:12.231577 (94.2%), Total CPU: 0:03:24.065108.
#          sample_id pcr_target  sars_cov2_avg_conc      sars_cov2_units  \
# 0      WSAC-220621          n             4362.81  copies/L wastewater
# 1      WSNB-221115          n                0.00                  NaN
# 2      WG0P-210817          n             3451.95  copies/L wastewater
# 3      WG0W-211102          n                0.00                  NaN
# 4      WM08-210720          n                0.00                  NaN
# ...            ...        ...                 ...                  ...
# 2346   WSNS-220830          n              842.00  copies/L wastewater
# 2347  WG02g-210427          n                0.00                  NaN
# 2348   WG0A-210622          n                0.00                  NaN
# 2349   WG0U-220817          n                0.03                  NaN
# 2350   WSGP-230222          n                0.05                  NaN
#
#            hum_frac_target_mic  hum_frac_mic_conc    hum_frac_mic_unit  \
# 0     pepper mild mottle virus                NaN                  NaN
# 1     pepper mild mottle virus                NaN                  NaN
# 2     pepper mild mottle virus       1.796511e+10  copies/L wastewater
# 3     pepper mild mottle virus       8.274900e+06  copies/L wastewater
# 4     pepper mild mottle virus       2.629636e+08  copies/L wastewater
# ...                        ...                ...                  ...
# 2346  pepper mild mottle virus       6.638179e+07  copies/L wastewater
# 2347  pepper mild mottle virus       1.250523e+08  copies/L wastewater
# 2348  pepper mild mottle virus       4.420366e+07  copies/L wastewater
# 2349  pepper mild mottle virus                NaN                  NaN
# 2350  pepper mild mottle virus       1.670553e+08  copies/L wastewater
#
#      other_norm_name  other_norm_conc      other_norm_unit inhibition_detect
# 0               qB2M              NaN                  NaN        Not tested
# 1               qB2M         87571.52  copies/L wastewater        Not tested
# 2               qB2M       3221867.95  copies/L wastewater        Not tested
# 3               qB2M         22714.31  copies/L wastewater        Not tested
# 4               qB2M        181743.53  copies/L wastewater        Not tested
# ...              ...              ...                  ...               ...
# 2346            qB2M        271359.02  copies/L wastewater        Not tested
# 2347            qB2M        281376.64  copies/L wastewater        Not tested
# 2348            qB2M        566884.33  copies/L wastewater        Not tested
# 2349            qB2M        126133.74  copies/L wastewater        Not tested
# 2350            qB2M       1863587.72  copies/L wastewater        Not tested
#
# [2351 rows x 11 columns]
#       age          job  marital  education default  balance housing loan  \
# 0      38   management   single   tertiary      no     7865     yes   no
# 1      23   management   single   tertiary      no     2681     yes   no
# 2      56      retired   single    primary      no     4113      no   no
# 3      27  blue-collar  married  secondary      no        3      no  yes
# 4      27  blue-collar  married    primary      no      276     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4516   36   management   single   tertiary      no       66      no   no
# 4517   27   management  married   tertiary      no     1772      no   no
# 4518   32   technician  married  secondary      no     2167     yes  yes
# 4519   32  blue-collar  married    primary      no      362     yes  yes
# 4520   30   technician   single   tertiary      no     2531     yes   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# 0     cellular   20   nov       321         1    175         2  failure   no
# 1     cellular    4   aug       202         2    458         1  success  yes
# 2     cellular   13   dec       194         1     -1         0  unknown   no
# 3     cellular    4   may       488         7     -1         0  unknown  yes
# 4      unknown    8   may       203         2     -1         0  unknown   no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ...
# 4516  cellular   26   aug       111        11     -1         0  unknown   no
# 4517   unknown    1   jun       543         1     -1         0  unknown   no
# 4518   unknown    6   may       572         2     -1         0  unknown  yes
# 4519  cellular   20   apr       102         2     -1         0  unknown   no
# 4520   unknown   28   may       149         1     -1         0  unknown   no
#
# [4521 rows x 17 columns]

# %% [markdown]
# ### Step 6.1: Inspect results
#
# For the data set we will do a simple visual comparison and calculate the descriptive statistics along with classification accuracy between the original vs. the synthesized data to determine the quality of synthesis

# %%
fig, axes = plt.subplots(ncols=2, nrows=2, figsize=(15, 10))
categorical_features = [f for f, a in features.items() if a["type"] in ("nominal", "ordinal")]
print(df.columns.drop(categorical_features))
for c, ax in zip(df.columns.drop(categorical_features), axes.flat):
    sns.kdeplot(ax=ax, x=df[c], color="dodgerblue", label="full_data", fill=True)
    sns.kdeplot(ax=ax, x=results.destination_data.get_dataframe()[c], color="orange", label="synth_data", fill=True)
    ax.set_xlabel(c)

fig.legend(labels=["full_data", "synth_data"])
fig.tight_layout()
plt.show()
# Out:
# Index(['sars_cov2_avg_conc', 'hum_frac_mic_conc', 'other_norm_conc'], dtype='object')

# %%
for name, result in sorted(results.validate_results.items()):
    display(Markdown(f"### {name} - Desirability: {result.desirability}"))
    display(Markdown(result.description))
    display(result.get_df())
# Out:
# ### AnonymityPreservation - Desirability: 5.0
# Measure how well the generated data preserve the privacy of the original data by comparing the distance from each generated case to its nearest original neighbor. This distance is divided by the smallest or average distance in that original neighbor's region, acting as a proxy for density called the distance ratio. If this ratio is at least 1, then privacy is maintained. If this ratio is at least 0.5, then plausible deniability is maintained. Desirability is computed on the worst case by default, with a desirability of 5 corresponding to a minimum distance ratio of 1 or greater. Also of note is the measured epsilon portion of the results. In differential privacy, this indicates the amount of the privacy budget that was actually consumed during synthesis. The total privacy budget is indicated by the `epsilon_upper_bound` parameter to `Synthesizer.synthesize_cases`, if specified.
#    run_number                              k    p new_case_threshold  \
# 0         1.0  (0.049787068367863944, 5, 20)  1.0                min
#
#    avg_distance_ratio  min_distance_ratio  measured_epsilon  desirability
# 0            2.190793                 1.0          1.187213           5.0
# ### DescriptiveStatistics - Desirability: 0.678
# Shows differences in `basic statistics` between the features of the original and generated data.
#      run_number dataset_label             feature  measure   measure_value  \
# 0           1.0      original  sars_cov2_avg_conc   median         244.285
# 1           1.0     generated  sars_cov2_avg_conc   median         3661.89
# 2           1.0      original  sars_cov2_avg_conc      std   823974.906109
# 3           1.0     generated  sars_cov2_avg_conc      std  3040042.441866
# 4           1.0      original  sars_cov2_avg_conc      25%             0.0
# ..          ...           ...                 ...      ...             ...
# 103         1.0     generated   inhibition_detect     mode      Not tested
# 104         1.0      original   inhibition_detect  uniques               1
# 105         1.0     generated   inhibition_detect  uniques               1
# 106         1.0      original   inhibition_detect  entropy               0
# 107         1.0     generated   inhibition_detect  entropy               0
#
#      desirability
# 0           0.001
# 1           0.001
# 2           0.001
# 3           0.001
# 4           0.001
# ..            ...
# 103         5.000
# 104         5.000
# 105         5.000
# 106         5.000
# 107         5.000
#
# [108 rows x 6 columns]
# ### FeatureImportanceComparison - Desirability: 1.523
# Builds and trains Trainees using original and generated data to compute Feature Robust Accuracy Contributions and Feature Robust Prediction Contributions. The feature importance rankings of the original and generated data are then compared using Rank-Biased Overlap (RBO) and Wasserstein Distance, also called Earth-Mover Distance (EMD), statistical methods. The geometric mean of the scaled RBO and EMD statistics is used as the desirability score. A desirability near 5 represents near similar feature importance rankings, desirability in the 4-3 range represents minor shuffling of important features, and a desirability of 2 or less represents the major shuffling of important features. Using the test_data argument can be used to give more accurate estimates by holding out data from both the original and the process used to generate data. However, by holding out test data from the data generation process, the generated data may be less accurate. The actual accuracy loss is expectation between the accuracy loss measured with and without using holdout test_data.
#     run_number       action_feature feature_importance_type      measure  \
# 0          1.0   sars_cov2_avg_conc                      ac          rbo
# 1          1.0   sars_cov2_avg_conc                      pc          rbo
# 2          1.0   sars_cov2_avg_conc                      ac  wasserstein
# 3          1.0   sars_cov2_avg_conc                      pc  wasserstein
# 4          1.0      other_norm_unit                      ac          rbo
# 5          1.0      other_norm_unit                      pc          rbo
# 6          1.0      other_norm_unit                      ac  wasserstein
# 7          1.0      other_norm_unit                      pc  wasserstein
# 8          1.0           pcr_target                      ac          rbo
# 9          1.0           pcr_target                      pc          rbo
# 10         1.0           pcr_target                      ac  wasserstein
# 11         1.0           pcr_target                      pc  wasserstein
# 12         1.0      other_norm_name                      ac          rbo
# 13         1.0      other_norm_name                      pc          rbo
# 14         1.0      other_norm_name                      ac  wasserstein
# 15         1.0      other_norm_name                      pc  wasserstein
# 16         1.0            sample_id                      ac          rbo
# 17         1.0            sample_id                      pc          rbo
# 18         1.0            sample_id                      ac  wasserstein
# 19         1.0            sample_id                      pc  wasserstein
# 20         1.0  hum_frac_target_mic                      ac          rbo
# 21         1.0  hum_frac_target_mic                      pc          rbo
# 22         1.0  hum_frac_target_mic                      ac  wasserstein
# 23         1.0  hum_frac_target_mic                      pc  wasserstein
# 24         1.0      other_norm_conc                      ac          rbo
# 25         1.0      other_norm_conc                      pc          rbo
# 26         1.0      other_norm_conc                      ac  wasserstein
# 27         1.0      other_norm_conc                      pc  wasserstein
# 28         1.0    hum_frac_mic_unit                      ac          rbo
# 29         1.0    hum_frac_mic_unit                      pc          rbo
# 30         1.0    hum_frac_mic_unit                      ac  wasserstein
# 31         1.0    hum_frac_mic_unit                      pc  wasserstein
# 32         1.0      sars_cov2_units                      ac          rbo
# 33         1.0      sars_cov2_units                      pc          rbo
# 34         1.0      sars_cov2_units                      ac  wasserstein
# 35         1.0      sars_cov2_units                      pc  wasserstein
# 36         1.0    hum_frac_mic_conc                      ac          rbo
# 37         1.0    hum_frac_mic_conc                      pc          rbo
# 38         1.0    hum_frac_mic_conc                      ac  wasserstein
# 39         1.0    hum_frac_mic_conc                      pc  wasserstein
# 40         1.0    inhibition_detect                      ac          rbo
# 41         1.0    inhibition_detect                      pc          rbo
# 42         1.0    inhibition_detect                      ac  wasserstein
# 43         1.0    inhibition_detect                      pc  wasserstein
#
#     measure_value  desirability
# 0    8.477229e-01         4.563
# 1    9.268477e-01         4.716
# 2    2.625498e+04         0.001
# 3    1.261669e+05         0.001
# 4    9.990234e-01         5.000
# 5    9.990234e-01         5.000
# 6    0.000000e+00         5.000
# 7    0.000000e+00         5.000
# 8    9.990234e-01         5.000
# 9    9.990234e-01         5.000
# 10   0.000000e+00         5.000
# 11   0.000000e+00         5.000
# 12   9.990234e-01         5.000
# 13   9.990234e-01         5.000
# 14   0.000000e+00         5.000
# 15   0.000000e+00         5.000
# 16   7.294519e-01         4.027
# 17   2.904312e-01         2.834
# 18   8.599550e-04         4.997
# 19   5.265800e-03         4.979
# 20   9.990234e-01         5.000
# 21   9.990234e-01         5.000
# 22   0.000000e+00         5.000
# 23   0.000000e+00         5.000
# 24   7.955977e-01         4.333
# 25   9.429610e-01         4.777
# 26   1.044551e+04         0.001
# 27   2.560418e+04         0.001
# 28   9.990234e-01         5.000
# 29   9.990234e-01         5.000
# 30   0.000000e+00         5.000
# 31   0.000000e+00         5.000
# 32   9.990234e-01         5.000
# 33   9.990234e-01         5.000
# 34   0.000000e+00         5.000
# 35   0.000000e+00         5.000
# 36   8.966068e-01         4.651
# 37   9.857437e-01         4.957
# 38   9.584993e+07         0.001
# 39   2.664922e+08         0.001
# 40   9.990234e-01         5.000
# 41   9.990234e-01         5.000
# 42   0.000000e+00         5.000
# 43   0.000000e+00         5.000
# ### JointProbability - Desirability: 4.339
# Measure how well the generated data capture the joint distribution of the original data by estimating the PDF of the data and computing the Jensen-Shannon divergence between both estimates.
#    run_number                              k    p        js  desirability
# 0         1.0  [0.049787068367863944, 5, 20]  1.0  0.132141         4.339
# ### ModelComparison - Desirability: 4.156
# Measure how well the generated data can act as a substitute for the original data by comparing model performance. Specifically, trains one model on a training set of the original data and one model on a training set of the generated data and evaluates them both against a test set of the original data. Desirability goes towards 5 as the performance becomes more similar. Degradations in performance of the generated model (e.g., lower accuracy) are punished more harshly than improvements in performance.
#     run_number dataset_label estimator       action_feature    measure  \
# 0          1.0           NaN     Howso      other_norm_unit       None
# 1          1.0           NaN     Howso           pcr_target       None
# 2          1.0           NaN     Howso      other_norm_name       None
# 3          1.0           NaN     Howso  hum_frac_target_mic       None
# 4          1.0           NaN     Howso    hum_frac_mic_unit       None
# 5          1.0           NaN     Howso      sars_cov2_units       None
# 6          1.0           NaN     Howso    inhibition_detect       None
# 7          1.0           NaN     Howso      other_norm_unit       None
# 8          1.0           NaN     Howso           pcr_target       None
# 9          1.0           NaN     Howso      other_norm_name       None
# 10         1.0           NaN     Howso  hum_frac_target_mic       None
# 11         1.0           NaN     Howso    hum_frac_mic_unit       None
# 12         1.0           NaN     Howso      sars_cov2_units       None
# 13         1.0           NaN     Howso    inhibition_detect       None
# 14         1.0      original     Howso   sars_cov2_avg_conc       rmse
# 15         1.0     generated     Howso   sars_cov2_avg_conc       rmse
# 16         1.0      original     Howso   sars_cov2_avg_conc         r2
# 17         1.0     generated     Howso   sars_cov2_avg_conc         r2
# 18         1.0      original     Howso   sars_cov2_avg_conc   spearman
# 19         1.0     generated     Howso   sars_cov2_avg_conc   spearman
# 20         1.0      original     Howso            sample_id        mcc
# 21         1.0     generated     Howso            sample_id        mcc
# 22         1.0      original     Howso            sample_id     recall
# 23         1.0     generated     Howso            sample_id     recall
# 24         1.0      original     Howso            sample_id  precision
# 25         1.0     generated     Howso            sample_id  precision
# 26         1.0      original     Howso            sample_id   accuracy
# 27         1.0     generated     Howso            sample_id   accuracy
# 28         1.0      original     Howso      other_norm_conc       rmse
# 29         1.0     generated     Howso      other_norm_conc       rmse
# 30         1.0      original     Howso      other_norm_conc         r2
# 31         1.0     generated     Howso      other_norm_conc         r2
# 32         1.0      original     Howso      other_norm_conc   spearman
# 33         1.0     generated     Howso      other_norm_conc   spearman
# 34         1.0      original     Howso    hum_frac_mic_conc       rmse
# 35         1.0     generated     Howso    hum_frac_mic_conc       rmse
# 36         1.0      original     Howso    hum_frac_mic_conc         r2
# 37         1.0     generated     Howso    hum_frac_mic_conc         r2
# 38         1.0      original     Howso    hum_frac_mic_conc   spearman
# 39         1.0     generated     Howso    hum_frac_mic_conc   spearman
#
#     measure_value  desirability
# 0             NaN           NaN
# 1             NaN           NaN
# 2             NaN           NaN
# 3             NaN           NaN
# 4             NaN           NaN
# 5             NaN           NaN
# 6             NaN           NaN
# 7             NaN           NaN
# 8             NaN           NaN
# 9             NaN           NaN
# 10            NaN           NaN
# 11            NaN           NaN
# 12            NaN           NaN
# 13            NaN           NaN
# 14   3.350039e+05      4.490000
# 15   9.218255e+05      4.490000
# 16  -1.137690e+00      3.000000
# 17  -1.518611e+01      3.000000
# 18   9.259209e-01      4.408000
# 19   8.369749e-01      4.408000
# 20   2.761739e-02      4.448000
# 21   4.036306e-02      4.448000
# 22   2.760085e-02      4.448000
# 23   4.033970e-02      4.448000
# 24   2.193914e-02      4.719000
# 25   2.806086e-02      4.719000
# 26   2.760085e-02      4.448000
# 27   4.033970e-02      4.448000
# 28   8.341219e+05      4.947000
# 29   7.488901e+05      4.947000
# 30   8.728481e-02      4.510723
# 31   2.642802e-01      4.510723
# 32   7.319866e-01      4.685000
# 33   7.732019e-01      4.685000
# 34   5.836749e+08      4.681000
# 35   1.569822e+09      4.681000
# 36   4.436487e-03      2.988909
# 37  -6.201582e+00      2.988909
# 38   7.136414e-01      3.058000
# 39   5.016771e-01      3.058000
